# %% [markdown]
# <a href="https://colab.research.google.com/github/JunheeChoi/coding_practice/blob/main/10953_A%2BB_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 백준 10953: A+B-6
# ![image.png](data:image/png;base64,...)

# %%
T = int(input())
for i in range(T):
    A,B = map(int, input().split(','))
    print(A+B)
# Out:
# 3
# 2,7
# 9
# 88,9421
# 9509
# 333333,13
# 333346
